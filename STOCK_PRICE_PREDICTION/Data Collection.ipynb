# %%
cd /content/drive/MyDrive/Stock Price Prediction/Google Stock Price Prediction
# Out:
# /content/drive/MyDrive/Stock Price Prediction/Google Stock Price Prediction

# %%
# !pip install pandas_datareader

# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr

# %%
API_KEY=input("Enter your API Key ")
# Out:
# Enter your API Key 4fc2b08a48b1a3336d28e92bbaa982882844855b

# %%
google_data=pdr.get_data_tiingo('GOOG',api_key=API_KEY)

# %%
google_data.head()
# Out:
#                                    close     high  ...  divCash  splitFactor
# symbol date                                        ...
# GOOG   2016-01-11 00:00:00+00:00  716.03  718.855  ...      0.0          1.0
#        2016-01-12 00:00:00+00:00  726.07  728.750  ...      0.0          1.0
#        2016-01-13 00:00:00+00:00  700.56  734.740  ...      0.0          1.0
#        2016-01-14 00:00:00+00:00  714.72  721.925  ...      0.0          1.0
#        2016-01-15 00:00:00+00:00  694.45  706.740  ...      0.0          1.0
#
# [5 rows x 12 columns]

# %%
google_data.describe()
# Out:
#              close         high  ...  divCash  splitFactor
# count  1257.000000  1257.000000  ...   1257.0       1257.0
# mean   1093.039387  1103.023356  ...      0.0          1.0
# std     270.201135   273.823642  ...      0.0          0.0
# min     668.260000   672.300000  ...      0.0          1.0
# 25%     841.650000   844.910000  ...      0.0          1.0
# 50%    1086.230000  1097.100000  ...      0.0          1.0
# 75%    1232.410000  1243.090000  ...      0.0          1.0
# max    1827.990000  1847.200000  ...      0.0          1.0
#
# [8 rows x 12 columns]

# %%
google_data.to_csv('google_dataset.csv',index_label=False)
